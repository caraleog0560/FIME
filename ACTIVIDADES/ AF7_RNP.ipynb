# %% [markdown]
# <a href="https://colab.research.google.com/github/caraleog0560/FIME/blob/main/ACTIVIDADES/%20AF7_RNP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AF7: Redes Neuronales Artificiales
# Carlos Alejandro Ochoa Garma 2042592 N4

# %% [markdown]
# # **1.- Cargar librerías.**

# %%
import numpy as np
from tensorflow.keras.datasets import mnist
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# # **2.- Cargar datos.**

# %%
# Cargar el dataset desde Keras como indica la instrucción
(train_data, train_labels), (test_data, test_labels) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# # **3.- Preprocesamiento de datos.**

# %%
# Aplanar las imágenes: de (28, 28) a (784,)
train_data_flat = train_data.reshape((train_data.shape[0], 28 * 28))
test_data_flat = test_data.reshape((test_data.shape[0], 28 * 28))

# Normalizar los datos
train_data_flat = train_data_flat.astype('float32') / 255
test_data_flat = test_data_flat.astype('float32') / 255

# %% [markdown]
# # **4.- Selección y entrenamiento del modelo.**

# %%
# Proponemos una estructura de 2 capas ocultas (100 y 50 neuronas)
# 'adam' es el optimizador y 'log-loss' es la función de pérdida por defecto
modelo_mlp = MLPClassifier(hidden_layer_sizes=(100, 50),
                            activation='relu',
                            solver='adam',
                            max_iter=10,
                            verbose=True)

# Entrenamiento usando la función fit
print("Iniciando entrenamiento con Scikit-learn...")
modelo_mlp.fit(train_data_flat, train_labels)
# Out:
# Iniciando entrenamiento con Scikit-learn...
# Iteration 1, loss = 0.43161659
# Iteration 2, loss = 0.17249449
# Iteration 3, loss = 0.12874975
# Iteration 4, loss = 0.09967536
# Iteration 5, loss = 0.08250647
# Iteration 6, loss = 0.06977709
# Iteration 7, loss = 0.05908567
# Iteration 8, loss = 0.05139314
# Iteration 9, loss = 0.04549307
# Iteration 10, loss = 0.03885133
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=10, verbose=True)

# %% [markdown]
# # **5.- Prueba del modelo.**

# %%
# Evaluación de la exactitud (accuracy)
predicciones_totales = modelo_mlp.predict(test_data_flat)
exactitud = accuracy_score(test_labels, predicciones_totales)
print(f"\nExactitud del modelo: {exactitud:.4f}")

# Realizar 5 predicciones individuales
print("\n--- 5 Predicciones del modelo ---")
for i in range(5):
    prediccion = modelo_mlp.predict(test_data_flat[i].reshape(1, -1))
    valor_real = test_labels[i]
    print(f"Muestra {i+1}: Predicción -> {prediccion[0]} | Valor Real -> {valor_real}")
# Out:
# Exactitud del modelo: 0.9739
#
# --- 5 Predicciones del modelo ---
# Muestra 1: Predicción -> 7 | Valor Real -> 7
# Muestra 2: Predicción -> 2 | Valor Real -> 2
# Muestra 3: Predicción -> 1 | Valor Real -> 1
# Muestra 4: Predicción -> 0 | Valor Real -> 0
# Muestra 5: Predicción -> 4 | Valor Real -> 4
